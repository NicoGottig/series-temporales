# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Series de Tiempo</h1>
#     <h3>Clase 8</h3>
#     <h3>Ejercicio 3</h3>
#         <p>Docentes: Rodrigo Del Rosso / Martin Masci<p>
# </div>

# %% [markdown]
# [Link de Facebook Prophet](https://facebook.github.io/prophet/docs/quick_start.html)

# %% [markdown]
# # Instalar e importar librerias

# %%
import warnings;
warnings.simplefilter('ignore')

# %%
# !pip install pystan
# !pip install pystan==2.19.1.1
# !pip install prophet

# %%
import pandas as pd
from prophet import Prophet

# %% [markdown]
# # Leer datos y procesar fechas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sebcalcagno/AnalisisSeriesTemporales/main/dataset.csv')

# %%
df.dtypes
# Out:
# Time Date      int64
# Product        int64
# Store         object
# Value        float64
# dtype: object

# %%
df['Year'] = df['Time Date'].apply(lambda x: str(x)[-4:])
df['Month'] = df['Time Date'].apply(lambda x: str(x)[-6:-4])
df['Day'] = df['Time Date'].apply(lambda x: str(x)[:-6])
df['ds'] = pd.DatetimeIndex(df['Year']+'-'+df['Month']+'-'+df['Day'])

# %%
df.head()
# Out:
#    Time Date  Product          Store     Value  Year Month Day         ds
# 0    1012018  2667437  QLD_CW_ST0203  2926.000  2018    01   1 2018-01-01
# 1    2012018  2667437  QLD_CW_ST0203  2687.531  2018    01   2 2018-01-02
# 2    3012018  2667437  QLD_CW_ST0203  2793.000  2018    01   3 2018-01-03
# 3    4012018  2667437  QLD_CW_ST0203  2394.000  2018    01   4 2018-01-04
# 4    5012018  2667437  QLD_CW_ST0203  2660.000  2018    01   5 2018-01-05

# %%
df = df.loc[(df['Product']==2667437) & (df['Store']=='QLD_CW_ST0203')]
df.drop(['Time Date', 'Product', 'Store', 'Year', 'Month', 'Day'], axis=1, inplace=True)
df.columns = ['y', 'ds']

# %%
df.dtypes
# Out:
# y            float64
# ds    datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#           y         ds
# 0  2926.000 2018-01-01
# 1  2687.531 2018-01-02
# 2  2793.000 2018-01-03
# 3  2394.000 2018-01-04
# 4  2660.000 2018-01-05

# %% [markdown]
# # Entreno el modelo

# %%
m = Prophet(interval_width=0.95, daily_seasonality=True)
model = m.fit(df)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx36hmuui/_pb3jy4f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx36hmuui/k28nqzc6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56198', 'data', 'file=/tmp/tmpx36hmuui/_pb3jy4f.json', 'init=/tmp/tmpx36hmuui/k28nqzc6.json', 'output', 'file=/tmp/tmpx36hmuui/prophet_model0xg1bi8c/prophet_model-20240412155831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:58:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:58:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Predicciones

# %%
future = m.make_future_dataframe(periods=100,freq='D')
forecast = m.predict(future)
forecast.head()
# Out:
#           ds        trend  yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2018-01-01  3041.771182  687.359162  3949.805081  3041.771182  3041.771182
# 1 2018-01-02  3042.521656  808.093683  3902.213319  3042.521656  3042.521656
# 2 2018-01-03  3043.272131  783.338086  4043.570084  3043.272131  3043.272131
# 3 2018-01-04  3044.022606  904.253219  4075.911525  3044.022606  3044.022606
# 4 2018-01-05  3044.773081  942.117061  4000.150854  3044.773081  3044.773081
#
#    additive_terms  additive_terms_lower  additive_terms_upper       daily  \
# 0     -640.520201           -640.520201           -640.520201  468.866564
# 1     -650.771051           -650.771051           -650.771051  468.866564
# 2     -625.066377           -625.066377           -625.066377  468.866564
# 3     -578.237548           -578.237548           -578.237548  468.866564
# 4     -614.374860           -614.374860           -614.374860  468.866564
#
#    ...     weekly  weekly_lower  weekly_upper       yearly  yearly_lower  \
# 0  ...  16.599243     16.599243     16.599243 -1125.986008  -1125.986008
# 1  ... -11.296388    -11.296388    -11.296388 -1108.341227  -1108.341227
# 2  ...  -4.417865     -4.417865     -4.417865 -1089.515076  -1089.515076
# 3  ...  22.477984     22.477984     22.477984 -1069.582096  -1069.582096
# 4  ... -34.571885    -34.571885    -34.571885 -1048.669539  -1048.669539
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0  -1125.986008                   0.0                         0.0
# 1  -1108.341227                   0.0                         0.0
# 2  -1089.515076                   0.0                         0.0
# 3  -1069.582096                   0.0                         0.0
# 4  -1048.669539                   0.0                         0.0
#
#    multiplicative_terms_upper         yhat
# 0                         0.0  2401.250981
# 1                         0.0  2391.750605
# 2                         0.0  2418.205755
# 3                         0.0  2465.785058
# 4                         0.0  2430.398221
#
# [5 rows x 22 columns]

# %%
forecast.tail()
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 1175 2021-03-22  4237.001097  2184.889218  5297.935685  4233.659526
# 1176 2021-03-23  4238.073097  2262.342770  5283.030015  4234.694816
# 1177 2021-03-24  4239.145096  2049.003757  5357.956882  4235.730107
# 1178 2021-03-25  4240.217095  2294.863724  5304.490900  4236.765398
# 1179 2021-03-26  4241.289095  2169.580160  5290.741248  4237.776509
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 1175  4240.449356     -514.326569           -514.326569           -514.326569
# 1176  4241.526718     -531.785870           -531.785870           -531.785870
# 1177  4242.599706     -517.247857           -517.247857           -517.247857
# 1178  4243.706688     -486.052084           -486.052084           -486.052084
# 1179  4244.814814     -542.659421           -542.659421           -542.659421
#
#            daily  ...     weekly  weekly_lower  weekly_upper      yearly  \
# 1175  468.866564  ...  16.599243     16.599243     16.599243 -999.792376
# 1176  468.866564  ... -11.296388    -11.296388    -11.296388 -989.356046
# 1177  468.866564  ...  -4.417865     -4.417865     -4.417865 -981.696556
# 1178  468.866564  ...  22.477984     22.477984     22.477984 -977.396632
# 1179  468.866564  ... -34.571885    -34.571885    -34.571885 -976.954101
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 1175   -999.792376   -999.792376                   0.0
# 1176   -989.356046   -989.356046                   0.0
# 1177   -981.696556   -981.696556                   0.0
# 1178   -977.396632   -977.396632                   0.0
# 1179   -976.954101   -976.954101                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 1175                         0.0                         0.0  3722.674528
# 1176                         0.0                         0.0  3706.287227
# 1177                         0.0                         0.0  3721.897239
# 1178                         0.0                         0.0  3754.165011
# 1179                         0.0                         0.0  3698.629673
#
# [5 rows x 22 columns]

# %%
forecast[['ds','yhat']]
# Out:
#              ds         yhat
# 0    2018-01-01  2401.250981
# 1    2018-01-02  2391.750605
# 2    2018-01-03  2418.205755
# 3    2018-01-04  2465.785058
# 4    2018-01-05  2430.398221
# ...         ...          ...
# 1175 2021-03-22  3722.674528
# 1176 2021-03-23  3706.287227
# 1177 2021-03-24  3721.897239
# 1178 2021-03-25  3754.165011
# 1179 2021-03-26  3698.629673
#
# [1180 rows x 2 columns]

# %%
m.changepoints
# Out:
# 35    2018-02-05
# 69    2018-03-11
# 104   2018-04-15
# 138   2018-05-19
# 173   2018-06-23
# 207   2018-07-27
# 242   2018-08-31
# 276   2018-10-04
# 311   2018-11-08
# 345   2018-12-12
# 380   2019-01-16
# 414   2019-02-19
# 449   2019-03-26
# 483   2019-04-29
# 518   2019-06-03
# 552   2019-07-07
# 587   2019-08-11
# 621   2019-09-14
# 656   2019-10-19
# 690   2019-11-22
# 725   2019-12-27
# 759   2020-01-30
# 794   2020-03-06
# 828   2020-04-09
# 863   2020-05-14
# Name: ds, dtype: datetime64[ns]

# %%
plot1 = m.plot(forecast)

# %%
plt2 = m.plot_components(forecast)

# %% [markdown]
# FIN DE LA CURSADA,
# <br>
# MUCHAS GRACIAS! 🤹
